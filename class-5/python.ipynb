# %%
def sum (x,y):
    z = x+y
    print (f"The sum of {x}&{y} is {z}")
    return z

sum (7,8)
sum (5.5,7.5)
sum (5,6.5)
# Out:
# The sum of 7&8 is 15
# The sum of 5.5&7.5 is 13.0
# The sum of 5&6.5 is 11.5
# 11.5

# %%
def calculate_rectangle_area(length, width):
  area = length*width
  print(f"The area of a rectangle with length {length} and width {width} is {area}")
  return area
length = int(input("Enter the length of the rectangle: "))
width = int(input("Enter the width of the rectangle: "))
calculate_rectangle_area(length,width)
# Out:
# The area of a rectangle with length 10 and width 6 is 60
# 60
