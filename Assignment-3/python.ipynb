# %%
class BankAccount:
    def __init__(self, name, account_number, balance=0):
        self.name = name
        self.account_number = account_number
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"Deposited Rs. {amount}")

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient funds")
        else:
            self.balance -= amount
            print(f"Withdrawn Rs. {amount}")

    def get_balance(self):
        print(f"Name: {self.name}")
        print(f"Account Number: {self.account_number}")
        print(f"Balance: Rs. {self.balance}")

# %%
accounts = [
    ("Ramesh Thapa", "A001", 5000),
    ("Sunita Karki", "A002", 0),
    ("Bikash Rai", "A003", 12000)
]

# %%
account1 = BankAccount(accounts[0][0], accounts[0][1], accounts[0][2])
account2 = BankAccount(accounts[1][0], accounts[1][1], accounts[1][2])
account3 = BankAccount(accounts[2][0], accounts[2][1], accounts[2][2])

# %%
# Deposit Rs. 3000 into A002
account2.deposit(3000)

# Withdraw Rs. 15000 from A003 (should fail)
account3.withdraw(15000)

# Withdraw Rs. 2000 from A001
account1.withdraw(2000)
# Out:
# Deposited Rs. 3000
# Insufficient funds
# Withdrawn Rs. 2000

# %%
print("Final Balance of Account 1")
account1.get_balance()

print("\nFinal Balance of Account 2")
account2.get_balance()

print("\nFinal Balance of Account 3")
account3.get_balance()
# Out:
# Final Balance of Account 1
# Name: Ramesh Thapa
# Account Number: A001
# Balance: Rs. 3000
#
# Final Balance of Account 2
# Name: Sunita Karki
# Account Number: A002
# Balance: Rs. 3000
#
# Final Balance of Account 3
# Name: Bikash Rai
# Account Number: A003
# Balance: Rs. 12000

# %%
class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

    def average(self):
        return sum(self.marks) / len(self.marks)

    def grade(self):
        avg = self.average()

        if avg >= 80:
            return "A"
        elif avg >= 65:
            return "B"
        elif avg >= 50:
            return "C"
        elif avg >= 40:
            return "D"
        else:
            return "F"

    def display(self):
        avg = self.average()

        if avg >= 40:
            result = "Pass"
        else:
            result = "Fail"

        print("Name:", self.name)
        print("Average:", round(avg, 2))
        print("Grade:", self.grade())
        print("Result:", result)

# %%
students = [
    ("Aarav", [78, 85, 60, 90, 72]),
    ("Sita", [45, 50, 38, 60, 55]),
    ("Gautam", [30, 25, 40, 35, 28]),
    ("Priya", [90, 88, 95, 92, 87])
]

# %%
student1 = Student(students[0][0], students[0][1])
student2 = Student(students[1][0], students[1][1])
student3 = Student(students[2][0], students[2][1])
student4 = Student(students[3][0], students[3][1])

# %%
student1.display()
print()

student2.display()
print()

student3.display()
print()

student4.display()
# Out:
# Name: Aarav
# Average: 77.0
# Grade: B
# Result: Pass
#
# Name: Sita
# Average: 49.6
# Grade: D
# Result: Pass
#
# Name: Gautam
# Average: 31.6
# Grade: F
# Result: Fail
#
# Name: Priya
# Average: 90.4
# Grade: A
# Result: Pass

# %%
class DeliveryPartner:
    def __init__(self, name, partner_id, deliveries):
        self.name = name
        self.partner_id = partner_id
        self.deliveries = deliveries

    def total_earning(self):
        pass

    def display(self):
        print("Name:", self.name)
        print("Partner ID:", self.partner_id)
        print("Deliveries:", self.deliveries)
        print("Total Earning: NPR", self.total_earning())
        print()

# %%
class BikeRider(DeliveryPartner):
    def __init__(self, name, partner_id, deliveries, km_travelled):
        super().__init__(name, partner_id, deliveries)
        self.km_travelled = km_travelled

    def total_earning(self):
        return (80 * self.deliveries) + (5 * self.km_travelled)

# %%
class Walker(DeliveryPartner):
    def __init__(self, name, partner_id, deliveries, rainy_deliveries):
        super().__init__(name, partner_id, deliveries)
        self.rainy_deliveries = rainy_deliveries

    def total_earning(self):
        return (60 * self.deliveries) + (50 * self.rainy_deliveries)

# %%
class CarDriver(DeliveryPartner):
    def __init__(self, name, partner_id, deliveries, fuel_cost):
        super().__init__(name, partner_id, deliveries)
        self.fuel_cost = fuel_cost

    def total_earning(self):
        return (120 * self.deliveries) - self.fuel_cost

# %%
partner1 = BikeRider("Santosh Rai", "B-01", 15, 42)
partner2 = Walker("Kabita Maharjan", "W-01", 18, 5)
partner3 = CarDriver("Roshan KC", "C-01", 20, 850)

partners = [partner1, partner2, partner3]

# %%
for partner in partners:
    partner.display()
# Out:
# Name: Santosh Rai
# Partner ID: B-01
# Deliveries: 15
# Total Earning: NPR 1410
#
# Name: Kabita Maharjan
# Partner ID: W-01
# Deliveries: 18
# Total Earning: NPR 1330
#
# Name: Roshan KC
# Partner ID: C-01
# Deliveries: 20
# Total Earning: NPR 1550

# %%
highest = partners[0]

for partner in partners:
    if partner.total_earning() > highest.total_earning():
        highest = partner

print("Highest Earning Partner")
print("Name:", highest.name)
print("Partner ID:", highest.partner_id)
print("Earning: NPR", highest.total_earning())
# Out:
# Highest Earning Partner
# Name: Roshan KC
# Partner ID: C-01
# Earning: NPR 1550

# %%
class Bus:
    def __init__(self, route, total_seats):
        self.route = route
        self.total_seats = total_seats
        self.booked = {}

    def book_seat(self, seat_number, passenger_name):
        if seat_number in self.booked:
            print("Seat already booked")
        else:
            self.booked[seat_number] = passenger_name
            print("Seat", seat_number, "booked for", passenger_name)

    def available_seats(self):
        return self.total_seats - len(self.booked)

    def passenger_list(self):
        print("Passenger List")
        for seat, passenger in self.booked.items():
            print("Seat", seat, "-", passenger)

# %%
bus = Bus("Kathmandu - Pokhara", 10)

# %%
bookings = [
    (3, "Ramila Shrestha"),
    (7, "Deepak Gurung"),
    (3, "Anita Rai"),      # duplicate
    (1, "Prakash Magar"),
    (7, "Suman Tamang")    # duplicate
]

# %%
for seat, passenger in bookings:
    bus.book_seat(seat, passenger)
# Out:
# Seat 3 booked for Ramila Shrestha
# Seat 7 booked for Deepak Gurung
# Seat already booked
# Seat 1 booked for Prakash Magar
# Seat already booked

# %%
print("Available Seats:", bus.available_seats())
# Out:
# Available Seats: 7

# %%
bus.passenger_list()
# Out:
# Passenger List
# Seat 3 - Ramila Shrestha
# Seat 7 - Deepak Gurung
# Seat 1 - Prakash Magar
